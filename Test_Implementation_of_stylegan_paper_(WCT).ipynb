# %% [markdown]
# <a href="https://colab.research.google.com/github/iamshant/fastbook/blob/master/Test_Implementation_of_stylegan_paper_(WCT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > # **Test Implementation of *stylegan paper***
#
#
# ## **[Photorealistic Style Transfer via Wavelet Transforms](https://github.com/clovaai/WCT2)**
#
# ### **[paper: Photorealistic Style Transfer via Wavelet Transforms](https://arxiv.org/abs/1903.09760)**

# %%
# !git clone https://github.com/clovaai/WCT2.git
# %cd WCT2

# for rummimg the code with the given data_set
# !python transfer.py --option_unpool cat5 -a --content ./examples/content --style ./examples/style --content_segment ./examples/content_segment --style_segment ./examples/style_segment/ --output ./outputs3/ --verbose --image_size 512

# output can be found on the output directory given in the output argument
# Out:
# Cloning into 'WCT2'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 143 (delta 2), reused 1 (delta 0), pack-reused 136
# Receiving objects: 100% (143/143), 112.76 MiB | 22.77 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# Checking out files: 100% (42/42), done.

# %%
# for running code with the datset from other code
# %cd ../
# !git clone https://github.com/luanfujun/deep-photo-styletransfer.git

# here we need to change the name of the style folder
# go to that style directory and run the bellow command by going to the directory
# !rename 's/tar/in/g' *.png


# the we need to run the python folder by changing the argument:  content, style, content_segment, style_segment, and outpur path which are taken from deep_photo_styletransfer repo
# content path is /deep-photo-styletransfer/examples/input
# style path is /deep-photo-styletransfer/examples/style
#segmentation path of content segment and style segment is same: /deep-photo-styletransfer/examples/segmentation
# !python transfer.py --option_unpool cat5 -a --content ./examples/content_2/ --style ./examples/style_2/ --content_segment ./examples/style_content_segment_2/ --style_segment ./examples/style_content_segment_2/ --output ./outputs2/ --verbose --image_size 512


# output can be found on the output directory given in the output argument

# %%
# %cd ../
# !git clone https://github.com/luanfujun/deep-photo-styletransfer.git
# Out:
# /content/drive/My Drive
# Cloning into 'deep-photo-styletransfer'...
# remote: Enumerating objects: 705, done.
# remote: Total 705 (delta 0), reused 0 (delta 0), pack-reused 705
# Receiving objects: 100% (705/705), 170.17 MiB | 23.66 MiB/s, done.
# Resolving deltas: 100% (185/185), done.
# Checking out files: 100% (434/434), done.

# %%
# !python transfer.py --option_unpool cat5 -a --content ./examples/content --style ./examples/style --content_segment ./examples/content_segment --style_segment ./examples/style_segment/ --output ./outputs/ --verbose --image_size 512
# Out:
# Namespace(alpha=1, content='./examples/content', content_segment='./examples/content_segment', cpu=False, image_size=512, option_unpool='cat5', output='./outputs/', style='./examples/style', style_segment='./examples/style_segment/', transfer_all=True, transfer_at_decoder=False, transfer_at_encoder=False, transfer_at_skip=False, verbose=True)
#   0% 0/6 [00:00<?, ?it/s]------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.432610
# ------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.045519
# ------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.235342
# ------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.914478
# ------ transfer: in58.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.216713
# ------ transfer: in58.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.907144
# ------ transfer: in58.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.856201
#  17% 1/6 [00:26<02:14, 26.89s/it]------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.695826
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.188955
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.470961
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.038936
# ------ transfer: in14.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.465715
# ------ transfer: in14.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.028240
# ------ transfer: in14.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.000291
#  33% 2/6 [00:45<01:37, 24.29s/it]------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.784343
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.251409
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.555885
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.125712
# ------ transfer: in17.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.533793
# ------ transfer: in17.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.085385
# ------ transfer: in17.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.112760
#  50% 3/6 [01:05<01:09, 23.21s/it]------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.868341
# ------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.323017
# ------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.691497
# ------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.154401
# ------ transfer: in00.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.717121
# ------ transfer: in00.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.120802
# ------ transfer: in00.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.075426
#  67% 4/6 [01:15<00:38, 19.25s/it]------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.092072
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.422076
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.791584
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.255818
# ------ transfer: in34.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.769828
# ------ transfer: in34.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.214782
# ------ transfer: in34.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.188087
#  83% 5/6 [01:36<00:19, 19.61s/it]------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.318104
# ------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.988144
# ------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.221222
# ------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.897425
# ------ transfer: in64.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.184688
# ------ transfer: in64.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.888544
# ------ transfer: in64.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.915139
# 100% 6/6 [01:44<00:00, 17.39s/it]

# %%
# !python transfer.py --option_unpool cat5 -a --content ./examples/content_2/ --style ./examples/style_2/ --content_segment ./examples/style_content_segment_2/ --style_segment ./examples/style_content_segment_2/ --output ./outputs2/ --verbose --image_size 512
# Out:
# Namespace(alpha=1, content='./examples/content_2/', content_segment='./examples/style_content_segment_2/', cpu=False, image_size=512, option_unpool='cat5', output='./outputs2/', style='./examples/style_2/', style_segment='./examples/style_content_segment_2/', transfer_all=True, transfer_at_decoder=False, transfer_at_encoder=False, transfer_at_skip=False, verbose=True)
#   0% 0/60 [00:00<?, ?it/s]------ transfer: in18.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.784085
# ------ transfer: in18.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.246008
# ------ transfer: in18.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.529604
# ------ transfer: in18.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.074955
# ------ transfer: in18.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.478750
# ------ transfer: in18.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.029686
# ------ transfer: in18.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.015544
#   2% 1/60 [00:25<25:02, 25.47s/it]------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.790513
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.271067
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.575531
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.123902
# ------ transfer: in17.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.529970
# ------ transfer: in17.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.100107
# ------ transfer: in17.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.120297
#   3% 2/60 [00:48<23:52, 24.69s/it]------ transfer: in40.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.825676
# ------ transfer: in40.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.869121
# ------ transfer: in40.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.443154
# ------ transfer: in40.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.612798
# ------ transfer: in40.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.417447
# ------ transfer: in40.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.535437
# ------ transfer: in40.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.508490
#   5% 3/60 [01:16<24:23, 25.68s/it]------ transfer: in3.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.783862
# ------ transfer: in3.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.285037
# ------ transfer: in3.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.546935
# ------ transfer: in3.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.141879
# ------ transfer: in3.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.521189
# ------ transfer: in3.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.093604
# ------ transfer: in3.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.084507
#   7% 4/60 [01:37<22:41, 24.32s/it]------ transfer: in39.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.751843
# ------ transfer: in39.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.258632
# ------ transfer: in39.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.532963
# ------ transfer: in39.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.112440
# ------ transfer: in39.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.495219
# ------ transfer: in39.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.079253
# ------ transfer: in39.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.059082
#   8% 5/60 [01:58<21:16, 23.21s/it]------ transfer: in36.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.557600
# ------ transfer: in36.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.064804
# ------ transfer: in36.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.339520
# ------ transfer: in36.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.931825
# ------ transfer: in36.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.326781
# ------ transfer: in36.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.926298
# ------ transfer: in36.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.923431
#  10% 6/60 [02:15<19:17, 21.43s/it]------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.796338
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.275825
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.571804
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.117650
# ------ transfer: in14.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.502573
# ------ transfer: in14.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.073684
# ------ transfer: in14.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.053976
#  12% 7/60 [02:35<18:39, 21.13s/it]------ transfer: in51.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.353907
# ------ transfer: in51.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.607053
# ------ transfer: in51.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.066314
# ------ transfer: in51.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.387861
# ------ transfer: in51.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.033164
# ------ transfer: in51.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.350823
# ------ transfer: in51.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.295542
#  13% 8/60 [02:59<18:54, 21.82s/it]------ transfer: in21.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.991710
# ------ transfer: in21.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.368032
# ------ transfer: in21.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.771684
# ------ transfer: in21.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.187517
# ------ transfer: in21.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.738349
# ------ transfer: in21.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.231149
# ------ transfer: in21.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.208994
#  15% 9/60 [03:19<18:09, 21.36s/it]------ transfer: in7.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.849479
# ------ transfer: in7.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.336146
# ------ transfer: in7.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.626018
# ------ transfer: in7.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.201108
# ------ transfer: in7.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.585813
# ------ transfer: in7.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.149338
# ------ transfer: in7.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.149155
#  17% 10/60 [03:43<18:32, 22.24s/it]------ transfer: in13.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.087492
# ------ transfer: in13.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.844063
# ------ transfer: in13.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.952507
# ------ transfer: in13.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.790228
# ------ transfer: in13.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.013111
# ------ transfer: in13.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.849413
# ------ transfer: in13.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.818150
#  18% 11/60 [03:59<16:27, 20.16s/it]------ transfer: in9.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.190382
# ------ transfer: in9.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.917019
# ------ transfer: in9.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.007858
# ------ transfer: in9.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.832535
# ------ transfer: in9.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.010531
# ------ transfer: in9.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.836931
# ------ transfer: in9.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.816673
#  20% 12/60 [04:15<15:18, 19.13s/it]------ transfer: in12.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:03.044465
# ------ transfer: in12.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.911110
# ------ transfer: in12.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.550412
# ------ transfer: in12.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.600004
# ------ transfer: in12.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.497449
# ------ transfer: in12.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.569293
# ------ transfer: in12.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.552552
#  22% 13/60 [04:41<16:32, 21.12s/it]------ transfer: in33.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.647080
# ------ transfer: in33.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.124244
# ------ transfer: in33.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.381741
# ------ transfer: in33.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.968364
# ------ transfer: in33.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.408077
# ------ transfer: in33.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.975015
# ------ transfer: in33.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.928279
#  23% 14/60 [04:58<15:09, 19.78s/it]------ transfer: in38.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.988232
# ------ transfer: in38.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.373125
# ------ transfer: in38.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.804441
# ------ transfer: in38.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.241194
# ------ transfer: in38.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.769049
# ------ transfer: in38.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.202593
# ------ transfer: in38.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.236404
#  25% 15/60 [05:20<15:27, 20.61s/it]------ transfer: in24.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.095638
# ------ transfer: in24.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.381877
# ------ transfer: in24.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.752148
# ------ transfer: in24.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.194537
# ------ transfer: in24.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.739324
# ------ transfer: in24.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.167655
# ------ transfer: in24.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.137648
#  27% 16/60 [05:41<15:04, 20.56s/it]------ transfer: in45.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.622617
# ------ transfer: in45.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.130319
# ------ transfer: in45.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.424414
# ------ transfer: in45.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.000670
# ------ transfer: in45.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.408808
# ------ transfer: in45.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.988154
# ------ transfer: in45.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.980096
#  28% 17/60 [05:58<13:59, 19.52s/it]------ transfer: in44.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.438498
# ------ transfer: in44.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.638234
# ------ transfer: in44.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.156538
# ------ transfer: in44.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.437819
# ------ transfer: in44.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.131198
# ------ transfer: in44.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.385704
# ------ transfer: in44.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.399705
#  30% 18/60 [06:23<14:47, 21.13s/it]------ transfer: in56.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.512136
# ------ transfer: in56.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.109787
# ------ transfer: in56.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.328521
# ------ transfer: in56.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.013675
# ------ transfer: in56.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.299636
# ------ transfer: in56.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.988917
# ------ transfer: in56.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.955091
#  32% 19/60 [06:42<14:01, 20.53s/it]------ transfer: in32.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.883867
# ------ transfer: in32.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.360007
# ------ transfer: in32.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.679164
# ------ transfer: in32.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.218312
# ------ transfer: in32.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.633962
# ------ transfer: in32.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.166642
# ------ transfer: in32.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.164327
#  33% 20/60 [07:03<13:48, 20.70s/it]------ transfer: in15.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.837718
# ------ transfer: in15.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.292464
# ------ transfer: in15.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.575800
# ------ transfer: in15.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.159991
# ------ transfer: in15.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.545352
# ------ transfer: in15.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.109907
# ------ transfer: in15.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.083508
#  35% 21/60 [07:23<13:22, 20.58s/it]------ transfer: in57.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.128530
# ------ transfer: in57.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.876380
# ------ transfer: in57.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.993549
# ------ transfer: in57.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.836364
# ------ transfer: in57.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.981334
# ------ transfer: in57.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.810275
# ------ transfer: in57.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.770162
#  37% 22/60 [07:40<12:21, 19.53s/it]------ transfer: in6.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.182810
# ------ transfer: in6.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.539772
# ------ transfer: in6.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.935195
# ------ transfer: in6.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.364396
# ------ transfer: in6.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.882970
# ------ transfer: in6.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.326843
# ------ transfer: in6.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.325293
#  38% 23/60 [08:05<13:02, 21.15s/it]------ transfer: in20.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.728792
# ------ transfer: in20.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.218836
# ------ transfer: in20.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.525790
# ------ transfer: in20.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.084946
# ------ transfer: in20.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.502037
# ------ transfer: in20.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.074521
# ------ transfer: in20.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.068191
#  40% 24/60 [08:25<12:30, 20.86s/it]------ transfer: in46.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.079318
# ------ transfer: in46.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.397987
# ------ transfer: in46.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.803611
# ------ transfer: in46.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.224733
# ------ transfer: in46.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.734568
# ------ transfer: in46.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.176595
# ------ transfer: in46.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.188360
#  42% 25/60 [09:07<15:52, 27.21s/it]------ transfer: in41.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.113402
# ------ transfer: in41.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.411537
# ------ transfer: in41.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.804746
# ------ transfer: in41.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.234751
# ------ transfer: in41.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.799410
# ------ transfer: in41.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.203659
# ------ transfer: in41.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.197058
#  43% 26/60 [09:29<14:22, 25.37s/it]------ transfer: in28.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.439986
# ------ transfer: in28.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.653150
# ------ transfer: in28.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.140880
# ------ transfer: in28.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.426536
# ------ transfer: in28.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.091374
# ------ transfer: in28.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.345236
# ------ transfer: in28.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.369598
#  45% 27/60 [09:58<14:34, 26.49s/it]------ transfer: in8.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:24.343278
# ------ transfer: in8.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:16.463954
# ------ transfer: in8.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:18.049101
# ------ transfer: in8.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:10.022005
# ------ transfer: in8.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:17.842972
# ------ transfer: in8.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:09.408829
# ------ transfer: in8.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:08.832461
#  47% 28/60 [11:45<27:01, 50.67s/it]------ transfer: in30.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.722125
# ------ transfer: in30.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.766466
# ------ transfer: in30.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.346095
# ------ transfer: in30.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.513702
# ------ transfer: in30.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.299908
# ------ transfer: in30.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.477377
# ------ transfer: in30.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.444848
#  48% 29/60 [12:09<22:07, 42.83s/it]------ transfer: in55.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.698996
# ------ transfer: in55.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.178192
# ------ transfer: in55.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.499479
# ------ transfer: in55.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.049062
# ------ transfer: in55.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.444825
# ------ transfer: in55.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.995818
# ------ transfer: in55.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.005588
#  50% 30/60 [13:07<23:38, 47.29s/it]------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.086456
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.464701
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.857872
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.289473
# ------ transfer: in34.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.826053
# ------ transfer: in34.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.258301
# ------ transfer: in34.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.227806
#  52% 31/60 [13:29<19:07, 39.57s/it]------ transfer: in4.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.803888
# ------ transfer: in4.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.302554
# ------ transfer: in4.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.572466
# ------ transfer: in4.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.146600
# ------ transfer: in4.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.550200
# ------ transfer: in4.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.109726
# ------ transfer: in4.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.110619
#  53% 32/60 [13:50<15:54, 34.08s/it]------ transfer: in1.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.200184
# ------ transfer: in1.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.539817
# ------ transfer: in1.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.924252
# ------ transfer: in1.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.339034
# ------ transfer: in1.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.869475
# ------ transfer: in1.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.298480
# ------ transfer: in1.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.279223
#  55% 33/60 [14:13<13:48, 30.67s/it]------ transfer: in54.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.706746
# ------ transfer: in54.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.240155
# ------ transfer: in54.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.535282
# ------ transfer: in54.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.091597
# ------ transfer: in54.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.505028
# ------ transfer: in54.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.069656
# ------ transfer: in54.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.041555
#  57% 34/60 [14:34<12:01, 27.76s/it]------ transfer: in59.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.150887
# ------ transfer: in59.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.500403
# ------ transfer: in59.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.893273
# ------ transfer: in59.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.248659
# ------ transfer: in59.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.855148
# ------ transfer: in59.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.224647
# ------ transfer: in59.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.210324
#  58% 35/60 [15:08<12:27, 29.88s/it]------ transfer: in25.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:03.889941
# ------ transfer: in25.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.355940
# ------ transfer: in25.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:03.286509
# ------ transfer: in25.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.926906
# ------ transfer: in25.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:03.173579
# ------ transfer: in25.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.842656
# ------ transfer: in25.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.845555
#  60% 36/60 [15:42<12:26, 31.08s/it]------ transfer: in27.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:03.543564
# ------ transfer: in27.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.167715
# ------ transfer: in27.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.970402
# ------ transfer: in27.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.816776
# ------ transfer: in27.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.935187
# ------ transfer: in27.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.751660
# ------ transfer: in27.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.754723
#  62% 37/60 [16:10<11:32, 30.11s/it]------ transfer: in48.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.199257
# ------ transfer: in48.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.566564
# ------ transfer: in48.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.948833
# ------ transfer: in48.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.378518
# ------ transfer: in48.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.892179
# ------ transfer: in48.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.322445
# ------ transfer: in48.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.352870
#  63% 38/60 [16:36<10:37, 29.00s/it]------ transfer: in49.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.205525
# ------ transfer: in49.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.606806
# ------ transfer: in49.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:02.012387
# ------ transfer: in49.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.414932
# ------ transfer: in49.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.914940
# ------ transfer: in49.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.353085
# ------ transfer: in49.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.376089
#  65% 39/60 [17:03<09:53, 28.24s/it]------ transfer: in60.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.080273
# ------ transfer: in60.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.481863
# ------ transfer: in60.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.838958
# ------ transfer: in60.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.265744
# ------ transfer: in60.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.782232
# ------ transfer: in60.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.230518
# ------ transfer: in60.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.201256
#  67% 40/60 [17:27<09:00, 27.02s/it]Traceback (most recent call last):
#   File "transfer.py", line 216, in <module>
#     run_bulk(config)
#   File "transfer.py", line 164, in run_bulk
#     style = open_image(_style, config.image_size).to(device)
#   File "/content/drive/My Drive/WCT2/utils/io.py", line 30, in open_image
#     image = Image.open(image_path)
#   File "/usr/local/lib/python3.6/dist-packages/PIL/Image.py", line 2862, in open
#     "cannot identify image file %r" % (filename if filename else fp)
# PIL.UnidentifiedImageError: cannot identify image file './examples/style_2/in23.png'
#  67% 40/60 [17:29<08:44, 26.23s/it]

# %%
mv  /content/drive/MyDrive/WCT2/examples/content_2/input/*png  /content/drive/MyDrive/WCT2/examples/content_2/

# %%
cp -R /content/drive/MyDrive/deep-photo-styletransfer/examples/segmentation/*png /content/drive/MyDrive/WCT2/examples/style_content_segment_2/

# %%
# it doesn't work om colab

# import os
# for file in os.listdir("/content/drive/MyDrive/WCT2/examples/style_2"):
#     if file[0:3] == 'tar':
#         # print(file)
#         os.rename(file, f"/content/drive/MyDrive/WCT2/examples/style_2/in{file[3:]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-106-353200e4744a> in <module>()
#       3     if file[0:3] == 'tar':
#       4         # print(file)
# ----> 5         os.rename(file, f"/content/drive/MyDrive/WCT2/examples/style_2/in{file[3:]}")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tar1.png' -> '/content/drive/MyDrive/WCT2/examples/style_2/in1.png'

# %%
# trying another method, but couldn't able to mak eit work

# %%bash
# for f in *.delete; do
#     for i in 
#     mv -- "$f" "${f%.delete}.png"
# done

# %%
# !rename 's/tar/in/g' *.png

# %%
ls
# Out:
# in10.png  in18.png  in25.png  in32.png  in3.png   in47.png  in54.png  in6.png
# in11.png  in19.png  in26.png  in33.png  in40.png  in48.png  in55.png  in7.png
# in12.png  in1.png   in27.png  in34.png  in41.png  in49.png  in56.png  in8.png
# in13.png  in20.png  in28.png  in35.png  in42.png  in4.png   in57.png  in9.png
# in14.png  in21.png  in29.png  in36.png  in43.png  in50.png  in58.png
# in15.png  in22.png  in2.png   in37.png  in44.png  in51.png  in59.png
# in16.png  in23.png  in30.png  in38.png  in45.png  in52.png  in5.png
# in17.png  in24.png  in31.png  in39.png  in46.png  in53.png  in60.png

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7166529416032521395, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4245230950701510983
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12336622198085296561
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14640891840
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 249559511700722724
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %% [markdown]
# ### Component-wise Stylization
# Only for option_unpool = sum version
#
# *   Only for option_unpool = sum version
# *   Full stylization

# %%
# @output3
# !python transfer.py --option_unpool sum -e -s --content ./examples/content --style ./examples/style --content_segment ./examples/content_segment --style_segment ./examples/style_segment/ --output ./outputs3/ --verbose --image_size 512
# Out:
# Namespace(alpha=1, content='./examples/content', content_segment='./examples/content_segment', cpu=False, image_size=512, option_unpool='sum', output='./outputs3/', style='./examples/style', style_segment='./examples/style_segment/', transfer_all=False, transfer_at_decoder=False, transfer_at_encoder=True, transfer_at_skip=True, verbose=True)
#   0% 0/6 [00:00<?, ?it/s]------ transfer: ./outputs3/in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.496590
#  17% 1/6 [00:16<01:22, 16.45s/it]------ transfer: ./outputs3/in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.805966
#  33% 2/6 [00:27<00:59, 14.82s/it]------ transfer: ./outputs3/in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.467338
#  50% 3/6 [00:37<00:40, 13.51s/it]------ transfer: ./outputs3/in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.167626
#  67% 4/6 [00:54<00:28, 14.30s/it]------ transfer: ./outputs3/in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.544885
#  83% 5/6 [00:55<00:10, 10.49s/it]------ transfer: ./outputs3/in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.111945
# 100% 6/6 [00:57<00:00,  9.57s/it]

# %% [markdown]
# * Low-frequency-only stylization

# %%
# !python transfer.py --option_unpool sum -e --content ./examples/content --style ./examples/style --content_segment ./examples/content_segment --style_segment ./examples/style_segment/ --output ./outputs4/ --verbose --image_size 512
# Out:
# Namespace(alpha=1, content='./examples/content', content_segment='./examples/content_segment', cpu=False, image_size=512, option_unpool='sum', output='./outputs4/', style='./examples/style', style_segment='./examples/style_segment/', transfer_all=False, transfer_at_decoder=False, transfer_at_encoder=True, transfer_at_skip=False, verbose=True)
#   0% 0/6 [00:00<?, ?it/s]------ transfer: ./outputs4/in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.112596
#  17% 1/6 [00:05<00:26,  5.40s/it]------ transfer: ./outputs4/in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.183727
#  33% 2/6 [00:15<00:27,  6.86s/it]------ transfer: ./outputs4/in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.848927
#  50% 3/6 [00:30<00:28,  9.35s/it]------ transfer: ./outputs4/in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.067332
#  67% 4/6 [00:42<00:20, 10.08s/it]------ transfer: ./outputs4/in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.736852
#  83% 5/6 [00:44<00:07,  7.48s/it]------ transfer: ./outputs4/in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.990467
# 100% 6/6 [00:53<00:00,  8.99s/it]

# %% [markdown]
# # Results
# * option_unpool = cat5 version

# %%
# !python transfer.py --option_unpool cat5 -a --content ./examples/content --style ./examples/style --content_segment ./examples/content_segment --style_segment ./examples/style_segment/ --output ./outputs5/ --verbose --image_size 512
# Out:
# Namespace(alpha=1, content='./examples/content', content_segment='./examples/content_segment', cpu=False, image_size=512, option_unpool='cat5', output='./outputs5/', style='./examples/style', style_segment='./examples/style_segment/', transfer_all=True, transfer_at_decoder=False, transfer_at_encoder=False, transfer_at_skip=False, verbose=True)
#   0% 0/6 [00:00<?, ?it/s]------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.804382
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.225868
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.521657
# ------ transfer: in14.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.088377
# ------ transfer: in14.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.498369
# ------ transfer: in14.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.053934
# ------ transfer: in14.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.047405
#  17% 1/6 [00:22<01:50, 22.19s/it]------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.321216
# ------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.038810
# ------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.233339
# ------ transfer: in64.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.927616
# ------ transfer: in64.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.208009
# ------ transfer: in64.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.898241
# ------ transfer: in64.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.928748
#  33% 2/6 [00:30<01:11, 18.00s/it]------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.785758
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.284473
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.583225
# ------ transfer: in17.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.153265
# ------ transfer: in17.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.550332
# ------ transfer: in17.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.116877
# ------ transfer: in17.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.158221
#  50% 3/6 [00:50<00:56, 18.70s/it]------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.452828
# ------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.070116
# ------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.276018
# ------ transfer: in58.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:00.965876
# ------ transfer: in58.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.239349
# ------ transfer: in58.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:00.948619
# ------ transfer: in58.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:00.921730
#  67% 4/6 [01:13<00:39, 19.92s/it]------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.900147
# ------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.335093
# ------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.717060
# ------ transfer: in00.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.158278
# ------ transfer: in00.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.693532
# ------ transfer: in00.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.138691
# ------ transfer: in00.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.085956
#  83% 5/6 [01:23<00:16, 16.96s/it]------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:02.130690
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.475712
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.871836
# ------ transfer: in34.png
# transfer at encoder 1
# transfer at encoder 2
# transfer at encoder 3
# transfer at encoder 4
# Elapsed time in whole WCT: 0:00:01.285702
# ------ transfer: in34.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.850597
# ------ transfer: in34.png
# transfer at decoder 4
# transfer at decoder 3
# transfer at decoder 2
# transfer at decoder 1
# Elapsed time in whole WCT: 0:00:01.233044
# ------ transfer: in34.png
# transfer at skip pool1
# transfer at skip pool2
# transfer at skip pool3
# Elapsed time in whole WCT: 0:00:01.216912
# 100% 6/6 [01:43<00:00, 17.32s/it]

# %%
# !rm -rf outputs*

# %%
# ls
